# %%
from sudokunet import SudokuNet 
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.datasets import mnist
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import classification_report
import sys
sys.path.append('/kaggle/usr/lib/sudokunet.py')

from sudokunet import SudokuNet

# %%
args = {
    "model": "/kaggle/working/model.h5"
}
INIT_LR = 1e-3
EPOCHS = 10
BS = 120

print("[INFO] accessing MNIST..........")
((trainData,trainLabels),(testData,testLabels)) = mnist.load_data()

trainData = trainData.reshape((trainData.shape[0],28,28,1))
testData = testData.reshape((testData.shape[0],28,28,1))

trainData = trainData.astype("float32")/255.0
testData = testData.astype("float32")/255.0

le = LabelBinarizer()
trainLabels = le.fit_transform(trainLabels)
testLabels = le.transform(testLabels)

print("[INFO] compiling model............")
opt = Adam(lr=INIT_LR)
model = SudokuNet.build(width=28,height=28,depth=1,classes=10)
model.compile(loss='categorical_crossentropy',optimizer = opt,metrics=["accuracy"])

print("[INFO] training network..........")
H  = model.fit(
     trainData,trainLabels,
     validation_data = (testData,testLabels),
     batch_size = BS,
     epochs = EPOCHS,
     verbose = 1)


print("[INFO] evaluating network...")
predictions = model.predict(testData)
print(classification_report(
	testLabels.argmax(axis=1),
	predictions.argmax(axis=1),
	target_names=[str(x) for x in le.classes_]))
# serialize the model to disk
print("[INFO] serializing digit model...")
model.save(args["model"], save_format="h5")
# Out:
# [INFO] accessing MNIST..........
# [INFO] compiling model............
# [INFO] training network..........
# Epoch 1/10
# 500/500 [==============================] - 4s 5ms/step - loss: 0.6357 - accuracy: 0.7913 - val_loss: 0.0826 - val_accuracy: 0.9748
# Epoch 2/10
# 500/500 [==============================] - 2s 5ms/step - loss: 0.2314 - accuracy: 0.9332 - val_loss: 0.0637 - val_accuracy: 0.9820
# Epoch 3/10
# 500/500 [==============================] - 3s 5ms/step - loss: 0.1707 - accuracy: 0.9514 - val_loss: 0.0481 - val_accuracy: 0.9859
# Epoch 4/10
# 500/500 [==============================] - 2s 5ms/step - loss: 0.1478 - accuracy: 0.9582 - val_loss: 0.0430 - val_accuracy: 0.9873
# Epoch 5/10
# 500/500 [==============================] - 2s 5ms/step - loss: 0.1259 - accuracy: 0.9644 - val_loss: 0.0388 - val_accuracy: 0.9887
# Epoch 6/10
# 500/500 [==============================] - 2s 5ms/step - loss: 0.1142 - accuracy: 0.9666 - val_loss: 0.0431 - val_accuracy: 0.9885
# Epoch 7/10
# 500/500 [==============================] - 2s 5ms/step - loss: 0.1066 - accuracy: 0.9697 - val_loss: 0.0344 - val_accuracy: 0.9904
# Epoch 8/10
# 500/500 [==============================] - 2s 5ms/step - loss: 0.1007 - accuracy: 0.9715 - val_loss: 0.0356 - val_accuracy: 0.9899
# Epoch 9/10
# 500/500 [==============================] - 2s 5ms/step - loss: 0.0883 - accuracy: 0.9744 - val_loss: 0.0387 - val_accuracy: 0.9900
# Epoch 10/10
# 500/500 [==============================] - 2s 5ms/step - loss: 0.0838 - accuracy: 0.9753 - val_loss: 0.0317 - val_accuracy: 0.9909
# [INFO] evaluating network...
# 313/313 [==============================] - 1s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       980
#            1       0.99      0.99      0.99      1135
#            2       0.99      1.00      0.99      1032
#            3       0.99      1.00      0.99      1010
#            4       0.99      0.99      0.99       982
#            5       0.98      0.99      0.99       892
#            6       0.99      0.99      0.99       958
#            7       0.99      0.99      0.99      1028
#            8       0.99      0.99      0.99       974
#            9       0.99      0.98      0.99      1009
#
#     accuracy                           0.99     10000
#    macro avg       0.99      0.99      0.99     10000
# weighted avg       0.99      0.99      0.99     10000
#
# [INFO] serializing digit model...
